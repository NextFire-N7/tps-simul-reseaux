# %% [markdown]
# # Simulation files de taille finie

# %%
import pandas as pd

# %% [markdown]
# ## MM1K

# %% [markdown]
# ```sh
# $lambda=22.0;
# $mu=33.0;
# $duration=1000.0; #sec
# ```

# %%
df = pd.read_csv('MM1Klambda22.csv', index_col=0, skiprows=1)
df.plot(logy=True, grid=True)

# %% [markdown]
# ## MD1K
#
# commenter 22 et 23\
# decommenter 24\
# ligne 46 : `set bytes [expr round ([$pktSize value])]` -> `set bytes [expr round ($pktSize)]`
#
# `./rejet.pl > blabla.csv`

# %% [markdown]
# ```sh
# $lambda=20.0;
# $mu=33.0;
# $duration=10000.0; #sec
# ```

# %%
df = pd.read_csv('MD1Kduration10000.csv', index_col=0, skiprows=1)
df.plot(y='Tx simu.', logy=True, grid=True)

# %% [markdown]
# ```sh
# $lambda=20.0;
# $mu=33.0;
# $duration=1000000.0; #sec
# ```
